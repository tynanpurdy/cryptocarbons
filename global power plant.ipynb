# %% [markdown]
# # Global Power Plant Data
#
# `Tynan Purdy`

# %% [markdown]
# ## Imports and Major Variables

# %%
import numpy as np
import pandas as pd
import csv
from pprint import pprint

path = "data\global-power-plants\global_power_plant_database.csv"

# %% [markdown]
# ### File Import to DataFrame

# %%
with open(path, encoding='utf8') as fin:
    ppd = pd.read_csv(fin, low_memory=False)

ppd.iloc[1:10]
# Out:
#   country country_long                                               name  \
# 1     AFG  Afghanistan                                       Kandahar DOG
# 2     AFG  Afghanistan                                       Kandahar JOL
# 3     AFG  Afghanistan      Mahipar Hydroelectric Power Plant Afghanistan
# 4     AFG  Afghanistan   Naghlu Dam Hydroelectric Power Plant Afghanistan
# 5     AFG  Afghanistan  Nangarhar (Darunta) Hydroelectric Power Plant ...
# 6     AFG  Afghanistan            Northwest Kabul Power Plant Afghanistan
# 7     AFG  Afghanistan  Pul-e-Khumri Hydroelectric Power Plant Afghani...
# 8     AFG  Afghanistan   Sarobi Dam Hydroelectric Power Plant Afghanistan
# 9     ALB      Albania                                         Bistrica 1
#
#       gppd_idnr  capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 1    WKS0070144        10.00   31.6700    65.7950        Solar         NaN
# 2    WKS0071196        10.00   31.6230    65.7920        Solar         NaN
# ...

# %% [markdown]
# Was having trouble opening the file due to an encode error that seemed to be triggered by a particular character. Code below is designed to locate that character.

# %%
with open(path, encoding='utf8') as fin:
    linenum = 1
    while True:
        cellnum = 0
        for cell in fin.readline().split(","):
            cellnum += 1
            try:
                if cell: print(({linenum:cellnum},cell))
            except: 
                print(f'failed on char {cellnum} on line {linenum}')
        linenum += 1
print('done')

# %% [markdown]
# Error turned out to be that the original file object needed to specify its encoding format, not at the dataframe declaration.

# %% [markdown]
# ## Removing Unwanted Data

# %%
ppd.iloc[0:5]
# Out:
#   country country_long                                              name  \
# 0     AFG  Afghanistan      Kajaki Hydroelectric Power Plant Afghanistan
# 1     AFG  Afghanistan                                      Kandahar DOG
# 2     AFG  Afghanistan                                      Kandahar JOL
# 3     AFG  Afghanistan     Mahipar Hydroelectric Power Plant Afghanistan
# 4     AFG  Afghanistan  Naghlu Dam Hydroelectric Power Plant Afghanistan
#
#    capacity_mw primary_fuel  generation_gwh_2013  generation_gwh_2014  \
# 0         33.0        Hydro                  NaN                  NaN
# 1         10.0        Solar                  NaN                  NaN
# 2         10.0        Solar                  NaN                  NaN
# 3         66.0        Hydro                  NaN                  NaN
# 4        100.0        Hydro                  NaN                  NaN
#
#    generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# ...

# %%
unwanted_columns = ['latitude',
                    'longitude',
                    'other_fuel1',
                    'other_fuel2',
                    'other_fuel3',
                    'commissioning_year',
                    'gppd_idnr',
                    'owner',
                    'source',
                    'url',
                    'geolocation_source',
                    'wepp_id',
                    'year_of_capacity_data',
                    'generation_data_source',
                    'generation_gwh_2018',
                    'generation_gwh_2019',
                    'estimated_generation_note_2013',
                    'estimated_generation_note_2014',
                    'estimated_generation_note_2015',
                    'estimated_generation_note_2016',
                    'estimated_generation_note_2017']
ppd.drop(unwanted_columns, axis=1, inplace=True)

# %%
ppd.iloc[0:4]
# Out:
#   country country_long                                           name  \
# 0     AFG  Afghanistan   Kajaki Hydroelectric Power Plant Afghanistan
# 1     AFG  Afghanistan                                   Kandahar DOG
# 2     AFG  Afghanistan                                   Kandahar JOL
# 3     AFG  Afghanistan  Mahipar Hydroelectric Power Plant Afghanistan
#
#    capacity_mw  latitude  longitude primary_fuel  generation_gwh_2013  \
# 0         33.0    32.322    65.1190        Hydro                  NaN
# 1         10.0    31.670    65.7950        Solar                  NaN
# 2         10.0    31.623    65.7920        Solar                  NaN
# 3         66.0    34.556    69.4787        Hydro                  NaN
#
#    generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# ...

# %% [markdown]
# ## Converting Column DataTypes

# %% [markdown]
# Columns with numeric values (gigawatt generation, capacity) converted to float.

# %%
numeric_columns = ['capacity_mw',
                   'generation_gwh_2013',
                   'generation_gwh_2014',
                   'generation_gwh_2015',
                   'generation_gwh_2016',
                   'generation_gwh_2017',
                   'estimated_generation_gwh_2013',
                   'estimated_generation_gwh_2014',
                   'estimated_generation_gwh_2015',
                   'estimated_generation_gwh_2016',
                   'estimated_generation_gwh_2017']
ppd[numeric_columns] = ppd[numeric_columns].apply(pd.to_numeric)
ppd[:10]['estimated_generation_gwh_2017']
# Out:
# 0    119.50
# 1     18.29
# 2     18.72
# 3    174.91
# 4    350.80
# 5     46.12
# 6       NaN
# 7     19.74
# 8     80.00
# 9     88.45
# Name: estimated_generation_gwh_2017, dtype: float64

# %%
ppd.iloc[0:5]
# Out:
#   country country_long                                              name  \
# 0     AFG  Afghanistan      Kajaki Hydroelectric Power Plant Afghanistan
# 1     AFG  Afghanistan                                      Kandahar DOG
# 2     AFG  Afghanistan                                      Kandahar JOL
# 3     AFG  Afghanistan     Mahipar Hydroelectric Power Plant Afghanistan
# 4     AFG  Afghanistan  Naghlu Dam Hydroelectric Power Plant Afghanistan
#
#    capacity_mw primary_fuel  generation_gwh_2013  generation_gwh_2014  \
# 0         33.0        Hydro                  NaN                  NaN
# 1         10.0        Solar                  NaN                  NaN
# 2         10.0        Solar                  NaN                  NaN
# 3         66.0        Hydro                  NaN                  NaN
# 4        100.0        Hydro                  NaN                  NaN
#
#    generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# ...

# %%
sources = []
for source in ppd['primary_fuel']:
    if source not in sources: sources.append(source)
sources
# Out:
# ['Hydro',
#  'Solar',
#  'Gas',
#  'Other',
#  'Oil',
#  'Wind',
#  'Nuclear',
#  'Coal',
#  'Waste',
#  'Biomass',
#  'Wave and Tidal',
#  'Petcoke',
#  'Geothermal',
#  'Storage',
#  'Cogeneration']

# %% [markdown]
# ## Adding Aggregate Data
