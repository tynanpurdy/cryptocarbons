# %% [markdown]
# # Final Project Phase 3 Summary
# This Jupyter Notebook (.ipynb) will serve as the skeleton file for your submission for Phase 3 of the Final Project. Complete all sections below as specified in the instructions for the project, covering all necessary details. We will use this to grade your individual code (Do this whether you are in a group or not). Good luck! <br><br>
#
# Note: To edit a Markdown cell, double-click on its text.

# %% [markdown]
# ## Jupyter Notebook Quick Tips
# Here are some quick formatting tips to get you started with Jupyter Notebooks. This is by no means exhaustive, and there are plenty of articles to highlight other things that can be done. We recommend using HTML syntax for Markdown but there is also Markdown syntax that is more streamlined and might be preferable.
# <a href = "https://towardsdatascience.com/markdown-cells-jupyter-notebook-d3bea8416671">Here's an article</a> that goes into more detail. (Double-click on cell to see syntax)
#
# # Heading 1
# ## Heading 2
# ### Heading 3
# #### Heading 4
# <br>
# <b>BoldText</b> or <i>ItalicText</i>
# <br> <br>
# Math Formulas: $x^2 + y^2 = 1$
# <br> <br>
# Line Breaks are done using br enclosed in < >.
# <br><br>
# Hyperlinks are done with: <a> https://www.google.com </a> or
# <a href="http://www.google.com">Google</a><br>

# %% [markdown]
# # Data Collection and Cleaning
#
#
# Transfer/update the data collection and cleaning you created for Phase II below. You may include additional cleaning functions if you have extra datasets. If no changes are necessary, simply copy and paste your phase II parsing/cleaning functions.

# %% [markdown]
# ## Downloaded Dataset Requirement

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from pprint import pprint
import requests
import json

# %%
def global_power():
  # IMPORT FILES
    generation_path = "/Users/katydickenson/Documents/CS2316/Homework/cryptocarbons/data/global-power-plants/global_power_plant_database.csv"
    emission_path = "/Users/katydickenson/Documents/CS2316/Homework/cryptocarbons/data/global-power-plants/global_power_emissions_database.xlsx"
  
  # power generation csv
    with open(generation_path, encoding='utf8') as fin:
        ppg = pd.read_csv(fin, low_memory=False)

  # power plant emissions xlsx
    ppe = pd.read_excel(emission_path, sheet_name='GPED_v1.0_Plant Level', skiprows=0, header=1)

  # removing unwanted data
    unwanted_columns = ['latitude',
                      'longitude',
                      'other_fuel1',
                      'other_fuel2',
                      'other_fuel3',
                      'commissioning_year',
                      'gppd_idnr',
                      'owner',
                      'source',
                      'url',
                      'geolocation_source',
                      'wepp_id',
                      'year_of_capacity_data',
                      'generation_data_source',
                      'generation_gwh_2018',
                      'generation_gwh_2019',
                      'estimated_generation_note_2013',
                      'estimated_generation_note_2014',
                      'estimated_generation_note_2015',
                      'estimated_generation_note_2016',
                      'estimated_generation_note_2017']
    ppg.drop(unwanted_columns, axis=1, inplace=True)

    unwanted_columns = ['No.', 'Number of Units', 'Total Plant Installed Capacity (MW)']
    ppe.drop(unwanted_columns, axis=1, inplace=True)

  # AGGREGATING DATA
    avgs = ['generation_gwh_2013',
          'generation_gwh_2014',
          'generation_gwh_2015',
          'generation_gwh_2016',
          'generation_gwh_2017']
    ppg['AVG_GENERATION'] = ppg[avgs].mean(axis=1)

    avgs = ['estimated_generation_gwh_2013',
          'estimated_generation_gwh_2014',
          'estimated_generation_gwh_2015',
          'estimated_generation_gwh_2016',
          'estimated_generation_gwh_2017']
    ppg['AVG_EST_GENERATION'] = ppg[avgs].mean(axis=1)

  # merge the two average columns into a single column
    ppg['GENERATION_MW'] = ppg.apply(lambda x : np.fmax(x['AVG_GENERATION'], x['AVG_EST_GENERATION']), axis=1)

  # remove unaggregated columns
    unwanted_columns = ['AVG_GENERATION',
                      'AVG_EST_GENERATION',
                      'generation_gwh_2013',
                      'generation_gwh_2014',
                      'generation_gwh_2015',
                      'generation_gwh_2016',
                      'generation_gwh_2017',
                      'estimated_generation_gwh_2013',
                      'estimated_generation_gwh_2014',
                      'estimated_generation_gwh_2015',
                      'estimated_generation_gwh_2016',
                      'estimated_generation_gwh_2017']
    ppg.drop(unwanted_columns, axis=1, inplace=True)

  # merge rows by fuel type
    generation_dist = ppg.groupby('primary_fuel')['GENERATION_MW'].sum().sort_values(ascending=False)
    emission_dist = ppe.groupby('Fuel Types').aggregate({'CO2 Emissions (Mg)':'sum',
                                                       'SO2 Emissions (Mg)':'sum',
                                                       'NOx Emissions (Mg)':'sum',
                                                       'PM2.5 Emissions (Mg)':'sum'})

  # COMBINING TABLES
    generation_dist.index = generation_dist.index.str.upper()
    generation_dist.drop('WAVE AND TIDAL', axis=0, inplace=True)
    gen_other = ['PETCOKE','WASTE','COGENERATION','STORAGE','NUCLEAR']
    generation_dist['OTHER'] = generation_dist[gen_other].sum(axis=0)
    generation_dist.drop(gen_other, axis=0, inplace=True)
    emission_dist = emission_dist.rename(index={'NG':'GAS'})

    power = pd.concat([generation_dist, emission_dist], axis=1)
    power = power.fillna(0)

    return power

############ Function Call ############
global_power()
# Out:
#             GENERATION_MW  CO2 Emissions (Mg)  SO2 Emissions (Mg)  \
# COAL         9.960694e+06        8.880799e+09        2.973419e+07
# GAS          6.304916e+06        2.518846e+09        5.228739e+04
# HYDRO        3.755360e+06        0.000000e+00        0.000000e+00
# WIND         7.094421e+05        0.000000e+00        0.000000e+00
# OIL          5.360917e+05        7.370139e+08        8.689335e+06
# SOLAR        3.486002e+05        0.000000e+00        0.000000e+00
# GEOTHERMAL   6.083382e+04        0.000000e+00        0.000000e+00
# BIOMASS      3.368912e+04        1.196067e+08        1.792376e+05
# OTHER        3.011469e+06        2.749785e+08        1.500827e+05
#
#             NOx Emissions (Mg)  PM2.5 Emissions (Mg)
# COAL              1.848038e+07          2.508320e+06
# GAS               3.440040e+06          4.144760e+04
# HYDRO             0.000000e+00          0.000000e+00
# WIND              0.000000e+00          0.000000e+00
# OIL               2.723445e+06          9.304416e+04
# SOLAR             0.000000e+00          0.000000e+00
# GEOTHERMAL        0.000000e+00          0.000000e+00
# BIOMASS           1.744930e+05          3.713316e+04
# OTHER             3.382073e+05          1.042250e+04

# %% [markdown]
# ## Web Collection Requirement \#1

# %%
def web_scrape(): 

    #creates a dict that connects to a list of all the HashRates of GPUs for easy iteration when creating visuals
    hashlist = []
    hashdict = {}
    finalhash = []
    url = requests.get('https://whattomine.com/gpus')
    soup = BeautifulSoup(url.text, 'html.parser')
    for hasher in soup.find_all('div',{'class' :'position-relative'}):
        for h in hasher.stripped_strings:
            hashlist.append(h)
            hashlist2=  hashlist[::2]
            hashdict['Hashrate(Millions of Hash Per Sec)'] = [z for z in hashlist2] 
            finalhash = [float(x[:-5]) for x in hashlist2]
    #return finalhash

            
    wattlist = []
    wattdict = {}
    for wat in soup.find_all('small',{'class':'text-muted position-absolute'}):
        for w in wat.stripped_strings:
            wattlist.append(int(w[-4:-1]))
    #return wattlist
            wattdict["Watt"] = [z for z in wattlist]
    
    #creates a dict that connects to a list of all the Revenues of GPUs for easy iteration when creating visuals
    revlist = []
    revdict = {}
    for rev in soup.find_all('td',{'class':'text-right table-success font-weight-bold'}):
        for r in rev.stripped_strings:
            revlist.append(r)
            revdict["24Hour Revenue"] = [z for z in revlist]
    
    #creates a dict that connects to a list of all the Names of GPUs
    namelist = []
    namedict = {}
    for name in soup.find_all('td'):
        for n in name.stripped_strings:
            namelist.append(n)
            if '(*)' in namelist:
                namelist.remove('(*)')
            namelist2 = namelist[1:650:16]
            namedict["GPU Model"] = [z for z in namelist2]

    # this dictionary matches GPU model to the hash rate and 24 hour revenue
    fulldict = {}
    for i in range(len(namelist2)):
        fulldict[namelist2[i]] = {"Hashrate(Millions of Hash Per Sec)":hashlist2[i],"24Hour Revenue": revlist[i]}
    
    #creates a data frame with the columns as GPU name and the index as the description 
    data = []
    data.append(finalhash)
    data.append(revlist)
    data.append(wattlist)
    df = pd.DataFrame(data, index= ['Hashrate','24 Hour Revenue','Watts'], columns = namelist2).T
    return df 

############ Function Call ############
web_scrape()
# Out:
#                               Hashrate 24 Hour Revenue Watts
# GeForce RTX 3090                   114           $8.29   320
# Radeon VII                          93           $6.91   200
# GeForce RTX 3080                  91.5           $6.71   230
# Radeon RX 6800                      64           $4.72   150
# Radeon RX 6900 XT                   64           $4.72   150
# Radeon RX 6800 XT                   64           $4.72   150
# GeForce RTX 3080 Ti                4.2           $4.61   280
# GeForce RTX 3060 Ti               58.1           $4.30   130
# GeForce RTX 3070                  58.1           $4.30   130
# Radeon RX 5700 XT                   55           $4.06   130
# Radeon RX 5700                      55           $4.06   130
# GeForce RTX 2080 Ti               55.2           $3.95   180
# GeForce RTX 3060 Unrestricted       48           $3.55   110
# Radeon RX Vega 64                   50           $3.51   190
# Radeon RX Vega 56                   49           $3.48   170
# Radeon RX 6700 XT                   48           $3.48   140
# GeForce RTX 3070 Ti                 35           $3.45   230
# Radeon RX 5600 XT                 40.5           $2.95   110
# GeForce RTX 2080 Super              41           $2.87   160
# GeForce RTX 2070                    40           $2.84   140
# GeForce RTX 2060 Super              40           $2.84   140
# GeForce RTX 2070 Super              40           $2.84   140
# GeForce RTX 2080                   2.6           $2.83   190
# GeForce RTX 3060                    37           $2.67   110
# GeForce GTX 1080 Ti                 39           $2.67   180
# GeForce GTX 1080                    34           $2.29   170
# GeForce GTX 1660 Super            29.3           $2.11    90
# Radeon RX 580 8GB                 30.5           $2.11   130
# GeForce RTX 2060                    30           $2.09   120
# Radeon RX 480 8GB                   30           $2.05   140
# GeForce GTX 1660 Ti                 28           $2.03    80
# GeForce GTX 1070 Ti                 29           $1.97   140
# Radeon RX 5500 XT 8GB               26           $1.85    90
# GeForce GTX 1070                    25           $1.65   140
# GeForce GTX 1660                    23           $1.63    80
# GeForce GTX 1060 6GB              22.5           $1.57    90
# Radeon R9 Fury                      17           $1.22   300
# Radeon RX 570 4GB                   13           $1.10   160
# Radeon RX 470 4GB                 12.5           $1.07   150
# GeForce GTX 1050 Ti                550           $0.53    70
# Radeon R9 380 4GB                   19           $0.50   150

# %% [markdown]
# ## Web Collection Requirement #2

# %%
#data with details on specific crypto - to utilize when visualizing 
def coin_info():
    url = requests.get('https://whattomine.com/coins.json')
    j = url.json()
    df = pd.DataFrame(j['coins'])
    coins = pd.Series(j['coins'].keys)
    df.rename(index=coins, inplace=True)
    return df.transpose()

############ Function Call ############
coin_info()
# Out:
#                         id       tag          algorithm block_time  \
# Ethereum               151       ETH             Ethash     13.827
# Nicehash-Ethash         15  NICEHASH             Ethash          1
# Ravencoin              234       RVN             KawPow       59.0
# EthereumClassic        162       ETC            Etchash    13.3878
# Nicehash-KawPow         45  NICEHASH             KawPow          1
# Ergo                   340       ERG          Autolykos      109.0
# Nicehash-Autolykos      48  NICEHASH          Autolykos          1
# Beam                   294      BEAM        BeamHashIII       60.0
# Nicehash-BeamV3         38  NICEHASH        BeamHashIII          1
# Vertcoin                 5       VTC           Verthash      155.0
# Zano                   330      ZANO           ProgPowZ      120.0
# Aeternity              297        AE        CuckooCycle      181.0
# QuarkChain             318       QKC             Ethash     9.8993
# MWC-CT31               323       MWC         Cuckatoo31       60.0
# Equilibria             341       XEQ     CryptoNightGPU      120.0
# Ryo                    260       RYO     CryptoNightGPU      252.0
# Nicehash-Cuckatoo31     36  NICEHASH         Cuckatoo31          1
# Conceal                305       CCX     CryptoNightGPU      121.0
# BitTubeCash            256      TUBE        CuckooCycle    14.9283
# Callisto               283       CLO             Ethash    13.0032
# Swap                   301       XWP        Cuckaroo29s    15.2556
# Ellaism                221      ELLA             Ethash    12.9695
# Nicehash-CuckooCycle    37  NICEHASH        CuckooCycle          1
# Vidulum                331       VDL       EquihashZero       60.0
# Etho                   306      ETHO             Ethash    13.0479
# Expanse                154       EXP             Ethash       21.0
# Zclassic               167       ZCL       EquihashZero       76.0
# Nicehash-NeoScrypt       3  NICEHASH          NeoScrypt          1
# HavenProtocol          279       XHV   CryptoNightHaven      119.0
# Zero                   210       ZER       EquihashZero      122.0
# Ubiq                   173       UBQ            Ubqhash       92.0
# Bloc                   312      BLOC   CryptoNightHaven      172.0
# Flux                   287      FLUX            ZelHash      120.0
# Grin-CT32              324      GRIN         Cuckatoo32       59.0
# Tent                   288      TENT              Zhash       60.0
# BitcoinGold            214       BTG              Zhash      604.0
# Nicehash-Cuckatoo32     43  NICEHASH         Cuckatoo32          1
# Trezarcoin             215       TZC          NeoScrypt       60.0
# Feathercoin              8       FTC          NeoScrypt       62.0
# Nicehash-Zhash          30  NICEHASH              Zhash          1
# Firo                   175      FIRO                MTP      305.0
# EtherGem               307      EGEM             Ethash    12.2182
# 01coin                 338       ZOC          NeoScrypt      157.0
# BitcoinZ               207      BTCZ              Zhash      159.0
# Aion                   272      AION   Equihash (210,9)       10.0
# Lethean                296      LTHN       CryptoNightR      120.0
# Masari                 273       MSR  CryptoNightFastV2       60.0
# BitCash                304      BITC               X25X       63.0
# Conflux                337       CFX            Octopus     1.1492
# Sinovate               277       SIN               X25X      123.0
# Nicehash-Octopus        47  NICEHASH            Octopus          1
# Metaverse              209       ETP             Ethash       20.0
# GoByte                 225       GBX          NeoScrypt      155.0
# Sumokoin               196      SUMO       CryptoNightR      241.0
# Nicehash-CryptoNightR   35  NICEHASH       CryptoNightR          1
# EtherSocial            320       ESN             Ethash      237.0
# Quantum R L            263       QRL            RandomX       61.0
# Monero                 101       XMR            RandomX      121.0
# Nicehash-RandomX        40  NICEHASH            RandomX          1
# Sero                   328      SERO            ProgPow    15.4596
#
#                       block_reward block_reward24 last_block   difficulty  \
# Ethereum                   2.36378        2.44943   12908200  6.93558e+15
# Nicehash-Ethash                  1              1          0            1
# Ravencoin                     5000           5000    1859476      52768.1
# EthereumClassic              3.104          3.104   13212034  2.85568e+14
# Nicehash-KawPow                  1              1          0            1
# Ergo                         67.51        67.5101     541349  1.41051e+15
# Nicehash-Autolykos               1              1          0            1
# Beam                            40             40    1342985  2.21491e+07
# Nicehash-BeamV3                  1              1          0            1
# Vertcoin                        25             25    1602775      93.3106
# Zano                             1              1    1162257   1.8745e+12
# Aeternity                  102.465        102.465     463898   3.0753e+06
# QuarkChain                  2.5168         2.5168    7228172  4.17253e+10
# MWC-CT31                      0.25           0.25     877643      59090.9
# Equilibria                  5.0428        5.06365     620407  3.00959e+07
# Ryo                         46.665         46.665     538984   1.2561e+08
# Nicehash-Cuckatoo31              1              1          0            1
# Conceal                          6        6.00102     819373     1.09e+08
# BitTubeCash                8.44544        8.44693    2082295        12560
# Callisto                      38.7           38.7    7963966  9.01188e+11
# Swap                       1.14097        1.14179    5659312         8064
# Ellaism                       4.91           4.91    9219515  3.52478e+10
# Nicehash-CuckooCycle             1              1          0            1
# Vidulum                        4.8            4.8    1427692      13.2082
# Etho                           0.6            0.6    7588582  1.64777e+11
# Expanse                          4              4    5106983  7.21219e+11
# Zclassic                   0.78125        0.78125    1249912       20.029
# Nicehash-NeoScrypt               1              1          0            1
# HavenProtocol              6.10342        6.10766     891531  2.62832e+09
# Zero                         3.645          3.645    1165368      26371.6
# Ubiq                             4              4    1627203  3.26242e+12
# Bloc                       14.5493        14.5533     814828   1.5829e+07
# Flux                          37.5           37.5     912439      1009.99
# Grin-CT32                       60             60    1324464       428462
# Tent                             6              6    1871707      63.4549
# BitcoinGold                   6.25           6.25     696615       159985
# Nicehash-Cuckatoo32              1              1          0            1
# Trezarcoin                      50             50    1947921       2.7486
# Feathercoin                     40             40    3769246      43.9754
# Nicehash-Zhash                   1              1          0            1
# Firo                          6.25           6.25     392971      833.681
# EtherGem                      0.96           0.96    8355891  7.76397e+10
# 01coin                      10.013         10.013     634133      1.04279
# BitcoinZ                     11875          11875     788820       1483.9
# Aion                           4.5            4.5    9382604  1.15746e+07
# Lethean                     285.95        285.961    1010123  8.23239e+07
# Masari                     2.54968        2.55135    1662322  5.10548e+07
# BitCash                        7.2            7.2    1477798      2.74347
# Conflux                    1.99696         1.9716   20486041  7.51714e+11
# Sinovate                     12.47          12.47     726011      3.04336
# Nicehash-Octopus                 1              1          0            1
# Metaverse                  1.49684        1.49686    5463423  2.32013e+12
# GoByte                     3.11953        3.11953     737097      13.9359
# Sumokoin                     97.92          97.92     571698  2.86927e+09
# Nicehash-CryptoNightR            1              1          0            1
# EtherSocial                      5              5    6304260  1.81389e+11
# Quantum R L                5.07498        5.07749    1630603  1.72804e+09
# Monero                    0.927107       0.934553    2413956  3.15371e+11
# Nicehash-RandomX                 1              1          0            1
# Sero                           4.4            4.4    5966806  4.70324e+11
#
#                       difficulty24          nethash  ... exchange_rate_curr  \
# Ethereum               7.17539e+15  501597158435896  ...                BTC
# Nicehash-Ethash                  1   38595457117615  ...                BTC
# Ravencoin                  52607.7    3841310060609  ...                BTC
# EthereumClassic        2.89878e+14   21330436044980  ...                BTC
# Nicehash-KawPow                  1    1307809638879  ...                BTC
# Ergo                   1.40477e+15   12940460639260  ...                BTC
# Nicehash-Autolykos               1     548460964031  ...                BTC
# Beam                   2.27971e+07           369151  ...                BTC
# Nicehash-BeamV3                  1           202075  ...                BTC
# Vertcoin                   99.8424       2585586021  ...                BTC
# Zano                   1.85781e+12      15620810123  ...                BTC
# Aeternity               2.4551e+06            16990  ...                BTC
# QuarkChain             4.84629e+10       8429939877  ...                BTC
# MWC-CT31                   68850.2              984  ...                BTC
# Equilibria             3.48513e+07           250798  ...                BTC
# Ryo                    1.21029e+08           498451  ...                BTC
# Nicehash-Cuckatoo31              1              438  ...                BTC
# Conceal                1.27688e+08           900826  ...                BTC
# BitTubeCash                12153.9              841  ...                BTC
# Callisto               9.17793e+11      69305130265  ...                BTC
# Swap                       7980.85              528  ...                BTC
# Ellaism                3.34712e+10       2717747159  ...                BTC
# Nicehash-CuckooCycle             1             4747  ...                BTC
# Vidulum                     21.191             1803  ...                BTC
# Etho                    1.6189e+11      12628655768  ...                BTC
# Expanse                7.20105e+11      34343776009  ...                BTC
# Zclassic                   24.0152             2158  ...                BTC
# Nicehash-NeoScrypt               1        267876215  ...                BTC
# HavenProtocol          2.39189e+09         22086752  ...                BTC
# Zero                       30523.6             5404  ...                BTC
# Ubiq                   3.70781e+12      35461072801  ...                BTC
# Bloc                   1.41507e+07            92028  ...                BTC
# Flux                       1026.79            68948  ...                BTC
# Grin-CT32                   417247             7262  ...                BTC
# Tent                         72.44             8663  ...                BTC
# BitcoinGold                 124060          2169863  ...                BTC
# Nicehash-Cuckatoo32              1               59  ...                BTC
# Trezarcoin                 1.94134        196752327  ...                BTC
# Feathercoin                30.8144       3046335921  ...                BTC
# Nicehash-Zhash                   1           599277  ...                BTC
# Firo                       834.968      11739776299  ...                BTC
# EtherGem               8.39445e+10       6354432479  ...                BTC
# 01coin                    0.604525         28526984  ...                BTC
# BitcoinZ                   1517.78            76453  ...                BTC
# Aion                   6.55977e+06          1157461  ...                BTC
# Lethean                7.69561e+07           686032  ...                BTC
# Masari                 4.60631e+07           850912  ...                BTC
# BitCash                     2.8086        187033359  ...                BTC
# Conflux                6.56618e+11     654119649959  ...                BTC
# Sinovate                   3.12042        106269380  ...                BTC
# Nicehash-Octopus                 1     193189416963  ...                BTC
# Metaverse              2.15948e+12     116006382935  ...                BTC
# GoByte                      12.133        386157082  ...                BTC
# Sumokoin               2.52804e+09         11905702  ...                BTC
# Nicehash-CryptoNightR            1            68266  ...                BTC
# EtherSocial            1.86016e+11        765354650  ...                BTC
# Quantum R L            1.68502e+09         28328521  ...                BTC
# Monero                 3.07902e+11       2606373227  ...                BTC
# Nicehash-RandomX                 1        255424350  ...                BTC
# Sero                   4.95534e+11      30422793539  ...                BTC
#
#                                 market_cap estimated_rewards  \
# Ethereum               $269,931,056,280.33           0.00265
# Nicehash-Ethash                      $0.00           0.00019
# Ravencoin                  $567,126,275.73          74.33829
# EthereumClassic          $6,444,343,824.22           0.08452
# Nicehash-KawPow                      $0.00           0.00011
# Ergo                       $169,249,359.05           0.73195
# Nicehash-Autolykos                   $0.00           0.00009
# Beam                        $44,200,622.84           6.89191
# Nicehash-BeamV3                      $0.00           0.00009
# Vertcoin                    $30,084,049.85           6.75521
# Zano                        $30,372,377.70           1.16772
# Aeternity                   $32,732,721.42          22.44384
# QuarkChain                 $100,673,852.03         197.23449
# MWC-CT31                    $53,967,243.75           0.59109
# Equilibria                   $1,830,080.93          32.71021
# Ryo                          $1,044,151.83          72.85078
# Nicehash-Cuckatoo31                  $0.00           0.00006
# Conceal                      $3,089,562.41          10.81622
# BitTubeCash                  $1,819,386.09           404.088
# Callisto                    $17,420,874.03         333.49396
# Swap                           $340,671.28          86.83466
# Ellaism                         $90,881.93        1048.47122
# Nicehash-CuckooCycle                 $0.00           0.00005
# Vidulum                        $151,124.01         157.31547
# Etho                         $3,968,871.18           28.1142
# Expanse                    $139,272,645.60          43.01424
# Zclassic                     $1,286,267.31          16.94867
# Nicehash-NeoScrypt                   $0.00           0.00004
# HavenProtocol               $41,801,040.84           0.57776
# Zero                         $1,080,978.73          19.90774
# Ubiq                         $8,942,292.70           9.50989
# Bloc                        $69,060,816.00         221.77529
# Flux                                 $0.00          16.43702
# Grin-CT32                   $22,193,690.28           5.51682
# Tent                         $1,072,561.30          62.37405
# BitcoinGold                $821,133,663.39           0.02596
# Nicehash-Cuckatoo32                  $0.00           0.00004
# Trezarcoin                     $301,272.62         889.10161
# Feathercoin                  $5,446,601.83          44.97683
# Nicehash-Zhash                       $0.00           0.00003
# Firo                        $60,658,651.03           0.27142
# EtherGem                       $287,044.21          94.80595
# 01coin                          $26,785.90         437.45571
# BitcoinZ                     $2,271,829.64        5312.94057
# Aion                        $60,443,001.60           4.30695
# Lethean                        $915,961.70         744.56801
# Masari                         $574,549.34          21.23482
# BitCash                        $245,804.32         129.73056
# Conflux                    $182,603,175.41           3.37395
# Sinovate                     $2,546,491.14         200.54309
# Nicehash-Octopus                     $0.00           0.00002
# Metaverse                    $9,876,063.72           5.01284
# GoByte                      $41,052,818.40           11.0074
# Sumokoin                     $1,713,607.51           7.34043
# Nicehash-CryptoNightR                $0.00           0.00001
# EtherSocial                          $0.00         191.79253
# Quantum R L                 $17,179,874.90           0.35776
# Monero                   $4,035,449,664.37           0.00036
# Nicehash-RandomX                     $0.00               0.0
# Sero                            $69,557.12          17.53503
#
#                       estimated_rewards24 btc_revenue btc_revenue24  \
# Ethereum                          0.00265  0.00015955    0.00015981
# Nicehash-Ethash                   0.00015   0.0001914    0.00015111
# Ravencoin                        74.56497   0.0001182    0.00011856
# EthereumClassic                   0.08326  0.00011023    0.00010859
# Nicehash-KawPow                   0.00011  0.00010959    0.00010715
# Ergo                              0.73494  0.00010086    0.00010127
# Nicehash-Autolykos                 0.0001  0.00009489    0.00009859
# Beam                              6.69605  0.00008525    0.00008283
# Nicehash-BeamV3                   0.00008  0.00008701    0.00008178
# Vertcoin                          6.31349  0.00008674    0.00008107
# Zano                              1.17818  0.00007236    0.00007301
# Aeternity                        28.11031  0.00005618    0.00007036
# QuarkChain                      170.06338  0.00008087    0.00006973
# MWC-CT31                          0.50744  0.00007728    0.00006634
# Equilibria                       28.39859  0.00007589    0.00006588
# Ryo                              75.59504  0.00006338    0.00006577
# Nicehash-Cuckatoo31               0.00006  0.00006298    0.00006432
# Conceal                           9.23816  0.00007463    0.00006374
# BitTubeCash                     417.53406  0.00006061    0.00006263
# Callisto                         327.4683   0.0000588    0.00005774
# Swap                             87.79038  0.00005644    0.00005706
# Ellaism                        1102.24722  0.00005242    0.00005511
# Nicehash-CuckooCycle              0.00005  0.00005412    0.00005447
# Vidulum                          98.90186  0.00008652     0.0000544
# Etho                             28.61204  0.00005145    0.00005236
# Expanse                          43.08065  0.00005205    0.00005213
# Zclassic                         14.18032  0.00006135    0.00005133
# Nicehash-NeoScrypt                0.00005  0.00004069     0.0000498
# HavenProtocol                      0.6353  0.00004384    0.00004821
# Zero                             17.21781  0.00005455    0.00004718
# Ubiq                              8.37009  0.00005202    0.00004578
# Bloc                            247.25576  0.00003992    0.00004451
# Flux                              16.1682  0.00004405    0.00004333
# Grin-CT32                          5.6651  0.00004016    0.00004124
# Tent                             54.68645  0.00004678    0.00004101
# BitcoinGold                       0.03347  0.00003172     0.0000409
# Nicehash-Cuckatoo32               0.00004   0.0000397    0.00004052
# Trezarcoin                      1252.3844  0.00002845    0.00004008
# Feathercoin                      64.16444  0.00002699     0.0000385
# Nicehash-Zhash                    0.00004  0.00003092    0.00003541
# Firo                                0.271  0.00003539    0.00003534
# EtherGem                         87.77743  0.00003641    0.00003371
# 01coin                          713.53181  0.00002012    0.00003282
# BitcoinZ                       5194.44131  0.00003188    0.00003117
# Aion                              7.59813  0.00001374    0.00002424
# Lethean                         796.33227  0.00002234    0.00002389
# Masari                           23.53662  0.00002039     0.0000226
# BitCash                         126.76086  0.00002205    0.00002155
# Conflux                           3.81351  0.00001868    0.00002111
# Sinovate                        195.70157  0.00002005    0.00001957
# Nicehash-Octopus                  0.00002  0.00001673    0.00001954
# Metaverse                         5.38548  0.00001639    0.00001761
# GoByte                            12.6312  0.00001178    0.00001352
# Sumokoin                          8.33101  0.00001189     0.0000135
# Nicehash-CryptoNightR             0.00001  0.00001348    0.00001228
# EtherSocial                      187.5129  0.00000307      0.000003
# Quantum R L                       0.36707  0.00000215    0.00000221
# Monero                            0.00037   0.0000021    0.00000217
# Nicehash-RandomX                      0.0   0.0000019    0.00000197
# Sero                             16.64374   0.0000001    0.00000009
#
#                       profitability profitability24 lagging   timestamp
# Ethereum                        100             100   False  1627390806
# Nicehash-Ethash                 120              95   False  1627390808
# Ravencoin                        74              74   False  1627390691
# EthereumClassic                  69              68   False  1627390821
# Nicehash-KawPow                  69              67   False  1627390806
# Ergo                             63              63   False  1627390737
# Nicehash-Autolykos               59              62   False  1627390807
# Beam                             53              52   False  1627390838
# Nicehash-BeamV3                  55              51   False  1627390807
# Vertcoin                         54              51   False  1627390698
# Zano                             45              46   False  1627390818
# Aeternity                        35              44   False  1627390721
# QuarkChain                       51              44   False  1627390820
# MWC-CT31                         48              42   False  1627390820
# Equilibria                       48              41   False  1627390816
# Ryo                              40              41   False  1627390268
# Nicehash-Cuckatoo31              39              40   False  1627390806
# Conceal                          47              40   False  1627390838
# BitTubeCash                      38              39   False  1627390738
# Callisto                         37              36   False  1627390816
# Swap                             35              36   False  1627390820
# Ellaism                          33              34   False  1627390820
# Nicehash-CuckooCycle             34              34   False  1627390808
# Vidulum                          54              34   False  1627390836
# Etho                             32              33   False  1627390821
# Expanse                          33              33   False  1627390734
# Zclassic                         38              32   False  1627390587
# Nicehash-NeoScrypt               26              31   False  1627390806
# HavenProtocol                    27              30   False  1627390737
# Zero                             34              30   False  1627390734
# Ubiq                             33              29   False  1627390815
# Bloc                             25              28   False  1627390707
# Flux                             28              27   False  1627390701
# Grin-CT32                        25              26   False  1627390823
# Tent                             29              26   False  1627390811
# BitcoinGold                      20              26   False  1627388069
# Nicehash-Cuckatoo32              25              25   False  1627390808
# Trezarcoin                       18              25   False  1627390720
# Feathercoin                      17              24   False  1627390739
# Nicehash-Zhash                   19              22   False  1627390807
# Firo                             22              22   False  1627390815
# EtherGem                         23              21    True  1627214441
# 01coin                           13              21   False  1627390724
# BitcoinZ                         20              20   False  1627390110
# Aion                              9              15   False  1627390814
# Lethean                          14              15   False  1627390738
# Masari                           13              14   False  1627390835
# BitCash                          14              13   False  1627390818
# Conflux                          12              13   False  1627390820
# Sinovate                         13              12   False  1627390723
# Nicehash-Octopus                 10              12   False  1627390808
# Metaverse                        10              11   False  1627390819
# GoByte                            7               8   False  1627390614
# Sumokoin                          7               8   False  1627390721
# Nicehash-CryptoNightR             8               8   False  1627390806
# EtherSocial                       2               2   False  1627390127
# Quantum R L                       1               1   False  1627390723
# Monero                            1               1   False  1627390727
# Nicehash-RandomX                  1               1   False  1627390807
# Sero                              0               0   False  1627390737
#
# [60 rows x 23 columns]

# %% [markdown]
# ## Additional Data Sets

# %%
def hash_history():
    path = "/Users/katydickenson/Documents/CS2316/Homework/cryptocarbons/data/blockchain-dot-com-hash-rate.json"
    hashes = pd.read_csv(path)
    return hashes
hash_history()
# Out:
#                Timestamp     hash-rate
# 0    2020-07-15 00:00:00  1.189935e+08
# 1    2020-07-16 00:00:00  1.172690e+08
# 2    2020-07-17 00:00:00  1.017481e+08
# 3    2020-07-18 00:00:00  1.120953e+08
# 4    2020-07-19 00:00:00  1.129576e+08
# ..                   ...           ...
# 360  2021-07-10 00:00:00  1.149524e+08
# 361  2021-07-11 00:00:00  8.924873e+07
# 362  2021-07-12 00:00:00  8.996272e+07
# 363  2021-07-13 00:00:00  9.710262e+07
# 364  2021-07-14 00:00:00  1.213783e+08
#
# [365 rows x 2 columns]

# %% [markdown]
# #Inconsistency Revisions
#  **If you were requested to revise your inconsistency section from Phase II, enter your responses here. Otherwise, ignore this section.**
#
# For each inconsistency (NaN, null, duplicate values, empty strings, etc.) you discover in your datasets, write at least 2 sentences stating the significance, how you identified it, and how you handled it.
#
# 1.
#
# 2.
#
# 3.
#
# 4. (if applicable)
#
# 5. (if applicable)

# %% [markdown]
# ## Data Sources
#
# Include sources (as links) to your datasets. If any of these are different from your sources used in Phase II, please <b>clearly</b> specify.
#
# *   Downloaded Dataset Source:global_power_plant_database.csv
# *   Web Collection #1 Source:https://whattomine.com/gpus
# *   Web Collection #2 Source:https://whattomine.com/coins.json

# %% [markdown]
# # Data Analysis
# For the Data Analysis section, you are required to utilize your data to complete the following:
#
# *   Create at least 5 insights
# *   Generate at least 3 data visualizations
# *   Export aggregated data to at least 1 summary file
#
# Create a function for each of the following sections mentioned above. Do not forget to fill out the explanation section for each function.
#
# Make sure your data analysis is not too simple. Performing complex aggregation and using modules not taught in class shows effort, which will increase the chance of receiving full credit.

# %% [markdown]
# # Graphical User Interface (GUI) Implementation
# If you decide to create a GUI for Phase II, please create a separate Python file (.py) to build your GUI. You must submit both the completed PhaseII.ipynb and your Python GUI file.

# %% [markdown]
# ## Insights

# %%
def insight1():
    df = web_scrape()
    avgwat = df['Watts'].sum()/len(df['Watts'])
    avghash = df['Hashrate'].sum()/len(df['Hashrate'])
    hash_pow = avgwat/((avghash*1000000) - 34599965.4) #how many watts it takes to produce a singular hash
    return hash_pow





############ Function Call ############
insight1()
# Out:
# 1.0601693848705725e-05

# %% [markdown]
# ### Insight 1 Explanation
#
# First, a sum of all the wattages and hashrates (in millions of hashes) for each of the most popular/most used GPU was found and then divided by the length of the data in the column. With these averages we can figure out how much cryptocurrency can be hashed using a watt of power. The average hash variable had to be multiplied by one million to account for the ratio of the data. Not all GPUs measured their hashes in millions though. Some were simply measured in hash per second. To account for this, the extra amount of hashes created by the multiplication of 1 million was removed and the singular hashes were added in. This returned an accurate result of 94324.55 which represents how the hashrate per one unit of power (watts). This information can further be used with other data we have accumulated.

# %%
def insight2():
    hash_pow = insight1()
    df = hash_history()
    hashrate = df['hash-rate'].sum()/len(df['hash-rate'])
    hashpd = hashrate*hash_pow
    return hashpd
    
    





############ Function Call ############
insight2()
# Out:
# 1473.570749077386

# %% [markdown]
# ### Insight 2 Explanation
# This data takes the hashrate over the course of a day and divides it by the amount of days in question. This results in an average hashrate over the course of a day. Using the amount of wattage it takes to produce a singular hash, we can multiply the two to see how many watts of power will be used per day. This can them be factored into later visualizations and compared to emissions.

# %%
def get_emissions():
    df = global_power()
    hash_pow = insight1()
    emissions = df.iloc[:,1:].sum()
    generator = df.iloc[:,1].sum()
    volume = hash_pow/(generator/emissions)
    return volume
get_emissions()





############ Function Call ############
#insight3()
# Out:
# CO2 Emissions (Mg)      1.058742e-05
# SO2 Emissions (Mg)      3.278574e-08
# NOx Emissions (Mg)      2.125432e-08
# PM2.5 Emissions (Mg)    2.273042e-09
# dtype: float64

# %% [markdown]
# ### Insight 3 Explanation
#
# Insert explanation here

# %%
def insight4():
  pass





############ Function Call ############
insight4()

# %% [markdown]
# ### Insight 4 Explanation
#
# Insert explanation here

# %%
def insight5():
  pass





############ Function Call ############
insight5()

# %% [markdown]
# ### Insight 5 Explanation
#
# Insert explanation here

# %% [markdown]
# ## Data Visualizations

# %%
def visual1():
  pass





############ Function Call ############
visual1()

# %% [markdown]
# ### Visualization 1 Explanation
#
# Insert explanation here

# %%
def visual2():
    df = hash_history()
    df.plot(x= 'Timestamp',y = 'hash-rate', color = 'pink', kind = 'scatter', xticks = [1,361])





############ Function Call ############
visual2()

# %% [markdown]
# ### Visualization 2 Explanation
#
# Insert explanation here

# %%
def visual3():
  pass





############ Function Call ############
visual3()

# %% [markdown]
# ### Visualization 3 Explanation
#
# Insert explanation here

# %% [markdown]
# ## Summary Files

# %%
def summary1():
  pass





############ Function Call ############
summary1()

# %% [markdown]
# # Cited Sources
#
# If you used any additional sources to complete your Data Analysis section, list them here:
#
#
# *   Example Module Documentation
# *   Example Stack Overflow Assistance

# %% [markdown]
# # Video Presentation
#
# If you uploaded your Video Presentation to Bluejeans, YouTube, or any other streaming services, please provide the link here:
#
#
# *   Video Presentation Link
#
#
# Make sure the video sharing permissions are accessible for anyone with the provided link.

# %% [markdown]
# # Submission
#
# Prior to submitting your notebook to Gradescope, be sure to <b>run all functions within this file</b>. We will not run your functions ourselves, so we must see your outputs within this file in order to receive full credit.
